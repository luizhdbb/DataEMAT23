# %% [markdown]
# # Systems Check Assignment

# %% [markdown]
# ## For this class, I hope to:

# %% [markdown]
# 1. Learn how to be more organized with my code
# 2. Learn Python
# 3. Learn how to analyze data
# 4. Develop my coding skills
# 5. Connect with other programmers

# %% [markdown]
# Another thing that interests me about Data in EMAT is learning how to use GitHub.

# %% [markdown]
# ### Using GitHub in this class is important to me because:

# %% [markdown]
# 1. I will get to interact with other programmers and look at how they organize and build their codes.
# 2. I will be able to publish my work there.

# %% [markdown]
# ![ea406c8bfd51646086963a0d9532a2a8.jpg](attachment:ea406c8bfd51646086963a0d9532a2a8.jpg)

# %% [markdown]
# ![laptop.gif](attachment:laptop.gif)
