# %% [markdown]
# Luiz Henrique Dal'Berto<br>
# 11/28/2023
# # ✧Data in Hand✧
#
# ![7aa9c6cf5e7d4cecf481f18b1d7a9d79e7aab85045b22203effb2dda409bc5b7.jpg](attachment:7aa9c6cf5e7d4cecf481f18b1d7a9d79e7aab85045b22203effb2dda409bc5b7.jpg)
# _Stardew Valley_
#
#
# ## ✧Collecting and Organizing the Data✧
#
# Collecting data for my crop and fish profit per-season analysis turned out to be a tougher challenge than I had anticipated. Since my analysis relies on Stardew Valley data, my initial plan was to scrape the Stardew wiki to gather the necessary information. However, I was unable to execute this method. Therefore, I manually gathered all the required information: names of crops and fishes, item type (crop or fish), their seasons, crops growth time, and sell prices categorized by rarity. Since I don't have experience in creating tables, I used ChatGPT to arrange all the collected data into a coherent table. I then transferred this organized data into Excel and converted the file to the CSV format. It's important to note a limitation of my analysis: I won't be considering external player factors that can influence the prices of crops and fishes, such as farming and fishing professions. The reason for this exclusion is because my analysis is targeted on how much profit the player can make during a seson without any additional boosts. Despite these limitations, I'm excited to explore the data and see the patterns within Stardew Valley's crop and fish economics.
# <hr>

# %% [markdown]
# In this code cell I am importing pandas to read the CSV file with the collected data

# %%
import pandas as pd

# %% [markdown]
# In this code cell, I assigned a list called col_names containing all the column names for the data (corresponding to the CSV file). I used pd.read_csv() to read the data and assign the specified column names to the columns in the DataFrame it creates. I delimited the cells by ";", and stored it in the variable 'cf'.

# %%
col_names = ["Name" , "Type" , "Grow Time" , "Normal Price", "Silver Price" , "Gold Price" , "Iridium Price"]
cf = pd.read_csv('/Users/luizdalberto/Documents/Data in EMAT/cropsandfish.csv', names = col_names, delimiter=';')

# %%
cf
# Out:
#              Name    Type  Grow Time  Normal Price  Silver Price  Gold Price  \
# Name         Type  Season  Grow Time  Normal Price  Silver Price  Gold Price
# Parsnip      Crop  Spring     4 days           35g           43g         52g
# Green Bean   Crop  Spring     3 days           40g           50g         60g
# Cauliflower  Crop  Spring    12 days          175g          218g        262g
# Potato       Crop  Spring     6 days           80g          100g        120g
# ...           ...     ...        ...           ...           ...         ...
# Mussel       Fish     Any          -           30g           37g         45g
# Shrimp       Fish     Any          -           60g             -           -
# Snail        Fish     Any          -           65g             -           -
# Periwinkle   Fish     Any          -           20g             -           -
# Oyster       Fish     Any          -           40g           50g         60g
#
#              Iridium Price
# ...
